# %%
from __future__ import print_function
# %matplotlib inline
from pylab import *

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

import skimage
from skimage import *
from skimage.color import *
from skimage import io
import numpy as np

# %%
#Ucitati sliku 'lena.png' i prigazati je

# %% [markdown]
# Prikazati osobine ucitane matrice

# %%
# Ucitati sliku 'lena.tif'
# Po cemu se razlikuju ucitane slike?

# %%
# Prikazati novu sliku

# %% [markdown]
# Indeksiranje i skaliranje

# %%
# Ucitati sliku 'dice.png'

# %%
# Sabrati dice.png i lena.png

# %%
# Ucitati sliku 'einstein.tif' i preslikati je u odnosu na horizontalu

# %%
import scipy
from scipy import io

# %%
# Ucitati masku 'einstein_mask.mat' i primeniti je na sliku

# %%
# Plotovati originalnu sliku, masku i filtriranu sliku
